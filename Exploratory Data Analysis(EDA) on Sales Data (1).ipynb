# %%
#1. Set Up Your Environment
  # Install Anaconda (if not already installed)
  # Launch Jupyter Notebook
  # Create a new notebook for this project
#2. Import Required Libraries
  # Import pandas, numpy, matplotlib, and seaborn
  #Set up matplotlib to display plots inline
#3. Load the Dataset
  # Download the "Global Superstore Dataset" from Kaggle
  # Use pandas to read the CSV file into a DataFrame
  # Display the first few rows of the data using `head()`

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

df = pd.read_csv('C:/Users/benbo/OneDrive/Desktop/Data Analysis Project Examps/Global_Superstore.csv')

# %%
#4. Data Exploration
#Check the shape of the DataFrame
#Display info about the DataFrame using `info()`
#Generate descriptive statistics using `describe()`
df.head()
# Out:
#    Row ID                  Order ID  Order Date   Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954  11/11/2014  11/13/2014   First Class
# 1   26341    IN-2014-JR162107-41675    2/5/2014    2/7/2014  Second Class
# 2   25330    IN-2014-CR127307-41929  10/17/2014  10/18/2014   First Class
# 3   13524   ES-2014-KM1637548-41667   1/28/2014   1/30/2014   First Class
# 4   47221   SG-2014-RH9495111-41948   11/5/2014   11/6/2014      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (1000, 24)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Row ID                  Order ID  Order Date   Ship Date       Ship Mode  \
# 0     40098  CA-2014-AB10015140-41954  11/11/2014  11/13/2014     First Class
# 1     26341    IN-2014-JR162107-41675    2/5/2014    2/7/2014    Second Class
# 2     25330    IN-2014-CR127307-41929  10/17/2014  10/18/2014     First Class
# 3     13524   ES-2014-KM1637548-41667   1/28/2014   1/30/2014     First Class
# 4     47221   SG-2014-RH9495111-41948   11/5/2014   11/6/2014        Same Day
# ..      ...                       ...         ...         ...             ...
# 995   24278   IN-2015-JF1541527-42095    4/1/2015    4/5/2015  Standard Class
# 996   36249  CA-2015-AS10225140-42347   12/9/2015  12/13/2015    Second Class
# 997   30517   IN-2014-CK1259592-41929  10/17/2014  10/19/2014    Second Class
# 998    1408   MX-2014-SS2014018-41658   1/19/2014   1/26/2014  Standard Class
# 999   20944  ID-2015-RP19855130-42348  12/10/2015  12/14/2015  Standard Class
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          1000 non-null   int64
#  1   Order ID        1000 non-null   object
#  2   Order Date      1000 non-null   object
#  3   Ship Date       1000 non-null   object
#  4   Ship Mode       1000 non-null   object
#  5   Customer ID     1000 non-null   object
#  6   Customer Name   1000 non-null   object
#  7   Segment         1000 non-null   object
#  8   Postal Code     194 non-null    float64
#  9   City            1000 non-null   object
#  10  State           1000 non-null   object
#  11  Country         1000 non-null   object
#  12  Region          1000 non-null   object
#  13  Market          1000 non-null   object
#  14  Product ID      1000 non-null   object
#  15  Category        1000 non-null   object
#  16  Sub-Category    1000 non-null   object
# ...

# %%
#5. Data Cleaning
#Check for missing values
print(df.isnull().sum())
# Out:
# Row ID              0
# Order ID            0
# Order Date          0
# Ship Date           0
# Ship Mode           0
# Customer ID         0
# Customer Name       0
# Segment             0
# Postal Code       806
# City                0
# State               0
# Country             0
# Region              0
# Market              0
# Product ID          0
# Category            0
# Sub-Category        0
# Product Name        0
# Sales               0
# Quantity            0
# Discount            0
# Profit              0
# Shipping Cost       0
# Order Priority      0
# dtype: int64

# %%
#Handle any missing or inconsistent data
df.dropna(inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Postal Code       0
# City              0
# State             0
# Country           0
# Region            0
# Market            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# dtype: int64

# %%
#Convert data types if necessary (e.g., dates to datetime objects)
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Order Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 194 entries, 0 to 996
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          194 non-null    int64
#  1   Order ID        194 non-null    object
#  2   Order Date      194 non-null    datetime64[ns]
#  3   Ship Date       194 non-null    datetime64[ns]
#  4   Ship Mode       194 non-null    object
#  5   Customer ID     194 non-null    object
#  6   Customer Name   194 non-null    object
#  7   Segment         194 non-null    object
#  8   Postal Code     194 non-null    float64
#  9   City            194 non-null    object
#  10  State           194 non-null    object
#  11  Country         194 non-null    object
#  12  Region          194 non-null    object
#  13  Market          194 non-null    object
#  14  Product ID      194 non-null    object
#  15  Category        194 non-null    object
#  16  Sub-Category    194 non-null    object
# ...

# %%
#6. Basic Analysis
#Calculate total sales and profit 
total_sales = df['Sales'].sum()

# %%
total_sales
# Out:
# 54535.08

# %%
total_profit = df['Profit'].sum()

# %%
total_profit
# Out:
# 12063.97

# %%
print(f'Total Sales: {total_sales}, Total Profit: {total_profit}')
# Out:
# Total Sales: 54535.08, Total Profit: 12063.97

# %%
#Identify top-selling products
top_products = df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)

# %%
print(top_products)
# Out:
# Product Name
# GBC Ibimaster 500 Manual ProClick Binding System           9892.74
# GBC DocuBind P400 Electric Binding System                  4355.17
# Canon Image Class D660 Copier                              2999.95
# GBC DocuBind 300 Electric Binding Machine                  2419.51
# Hon 5100 Series Wood Tables                                2036.86
# Bady BDG101FRU Card Printer                                1439.98
# Avaya IP Phone 1140E VoIP phone                            1394.95
# Global Adaptabilites Bookcase, Cherry/Storm Gray Finish    1292.94
# Tennsco Single-Tier Lockers                                1126.02
# Ibico Ibimaster 300 Manual Binding System                  1103.97
# Name: Sales, dtype: float64

# %%
#Analyze sales by region
sales_by_region =df.groupby('Region')['Sales'].sum()
print(sales_by_region)
# Out:
# Region
# Central US     17187.94
# Eastern US     12256.44
# Southern US     8360.75
# Western US     16729.95
# Name: Sales, dtype: float64

# %%
#Examine the relationship between sales and profit (correlation between sales and profit)
correlation= df['Sales'].corr(df['Profit'])
print(f'Relationship between Sales and Profit: {correlation}')
# Out:
# Relationship between Sales and Profit: 0.9313979948257132

# %%
#7. Data Visualization
#Create a bar chart of sales by product category 
sns.barplot(x='Category', y='Sales', data=df)
plt.title('Sales by Product Category')
plt.show()

# %%
#Plot a line graph of monthly sales over time
#a, creating a new month colum from Order Date
df['Month'] = df['Order Date'].dt.to_period('M')
#b, calculation of monthly sales
monthly_sales = df.groupby('Month')['Sales'].sum()
#c, making sure the index is in a datetime format for plotting
monthly_sales.index= monthly_sales.index.to_timestamp()
# Plotting the line graph
monthly_sales.plot(kind='line')
plt.title('Monthly Sales Over Time')
plt.show()

# %%
#Generate a scatter plot of sales vs. profit
sns.scatterplot(x='Sales', y='Profit', data=df)
plt.title('Sales vs Profit')
plt.show()

# %%
#Produce a heatmap of sales by region and product category
#a, Pivot table for Sales by Region and Product Category
pivot_table = df.pivot_table(values='Sales', index='Region', columns='Category', aggfunc='sum')
#Creating the heatmap
sns.heatmap(pivot_table, annot=True, fmt='.0f')
plt.title('Sales by Region and Product Category')
plt.show()

# %%
#8. Derive Insights
#Based on your analysis and visualizations, list 3-5 key insights about GlobalMart's sales performance

# 1:Overall upward sales trend from 2012 to 2015
# 2:Major sales spike in early 2015
# 3:Increased sales voltality after mid 2014
# 4:Sharp increase in trend around mid 2014, establishing at higher levels
# 5:Consistent seasonal patterns troughout the years

# %%
#9. Bonus Challenge
#Perform a simple time series analysis to identify any sales trends or seasonality
#Seasonal Decomposition of Time Series (monthly sales)
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(monthly_sales, model='additive', period=12)
result.plot()
plt.show()

# %%
#10. Prepare a Summary
#Write a brief report (300-500 words) summarizing your findings and recommendations for GlobalMart

    #1, Which product categories are the most profitable?
#It can be seen from the graph that the Technology and Furniture products have the highest sales and variability, 
#The Office supplies perform lower but still consistent. Whilst Techonolgy and Furniture products constantly perform better
# the Office Supplies still can drive in good profit numbers
# Suggestions: Investigate how the Office Supplies sales could be driven focusing on the key region 
#that provides the highest amount of sales and profits as it will be seen from the sales and profit by region part.
    #2, Are there any noticable trends in sales over time?
#As the analysis shows there were around 3 noticable spikes and one outstanding perfomance in monthly sales.
#The data shows that the sales are constantly around the 2000 quantitites however the big surge in late 2014, beggining of 2015 reached the 4000's
 #Suggestions: Further anaylising those periods could reveal what caused the uptrend in the sales, it might have been a predictable force to calculate.
    #3, How do sales and profits vary by region?
#As it has been revealed, the Western US region provides over 5000 sales in Technology and over 6000 sales in Furniture.
#The other regions have a constant sale numbers around the 2000's, however there are a couple of regions where Technology and Furniture underperform in sales
#The most noticable is the sales of Office Suplies in the Central US rising to over 12000
#Suggestions: Further analyse the underperforming regions to find the cause of the low sale number.
#Targer the Central US with all possible resources to further drive up the Office Suply sales!
#4, Is there a correlation between discount and profit?
 #4,a. Calculation of the total discount and total profit
total_discount = df['Discount'].sum()
total_profit = df['Profit'].sum()
 #4,b. Convertion the Discount and Profit columns to numeric
df['Discount'] = pd.to_numeric(df['Discount'], errors='coerce')
df['Profit'] = pd.to_numeric(df['Profit'], errors='coerce')
 #4,c.Calculation of the correlation between discount and profit
discount_profit_correlation = df[['Discount', 'Profit']].corr().iloc[0, 1]

total_discount, total_profit, discount_profit_correlation
# Out:
# (29.95, 12063.97, -0.16262271039478665)

# %%
#Is there a correlation between discount and profit?
    #Yes the correlation suggests that the higher the discount is the lower the profit will go.
